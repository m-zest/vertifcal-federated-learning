# %%
# !pip install pyfhel pandas scikit-learn
# Out:
# ...
#   Using cached Pyfhel-3.4.2.tar.gz (1.0 MB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'error'
#   error: subprocess-exited-with-error
#
#   Getting requirements to build wheel did not run successfully.
#   exit code: 1
#
#   [33 lines of output]
#   Traceback (most recent call last):
#     File "C:\Users\zeesh\anaconda3\Lib\site-packages\pip\_vendor\pyproject_hooks\_in_process\_in_process.py", line 353, in <module>
#       main()
#     File "C:\Users\zeesh\anaconda3\Lib\site-packages\pip\_vendor\pyproject_hooks\_in_process\_in_process.py", line 335, in main
#       json_out['return_val'] = hook(**hook_input['kwargs'])
#                                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ...

# %%
import pandas as pd

dataset1 = pd.read_csv("dataset1.csv")  
dataset2 = pd.read_csv("dataset2.csv")  

print("Party A sample:")
print(dataset1.head())

print("Party B sample:")
print(dataset2.head())

# %%
from Pyfhel import Pyfhel

HE = Pyfhel()
HE.contextGen(p=65537)   # Generate context with plaintext modulus p
HE.keyGen()             # Generate key pair (public/private keys)

# %%
# Party A (dataset1): sum of dr and x0...x9 per sample
partyA_features = dataset1[['dr'] + [f'x{i}' for i in range(10)]].sum(axis=1)

# Party B (dataset2): just use 'ar' as local feature for example
partyB_features = dataset2['ar']
